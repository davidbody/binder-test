# %% [markdown]
# Time Alice and Bob face each other is
#
# $\Delta t = \frac{\alpha - 1}{\alpha^2 + \alpha} $
#
# This is maximimzed when
#
# $\alpha = 1 + \sqrt{2}$

# %%
dt(alpha) = (alpha - 1) / (alpha^2 + alpha)
# Out:
# dt (generic function with 1 method)

# %%
alpha = 1:0.1:4
# Out:
# 1.0:0.1:4.0

# %%
solution = 1 + √2
# Out:
# 2.414213562373095

# %%
time_facing = dt.(alpha);

# %%
using Plots
pyplot()
plot(alpha, time_facing)
plot!([solution], seriestype = :vline)
